# %% [markdown]
# <a href="https://colab.research.google.com/github/Ady-92/task-on-student-performance-based-on-studied-hours.ipynb/blob/main/AdyPuna_on_Data_exploratory_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import pandas as pd

dff = pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# # understanding the data

# %%
dff.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
dff.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
dff.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
dff.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
dff.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
dff.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
len(dff)
# Out:
# 9994

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
dff.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Visualizing the data

# %%
dff.plot.hist(figsize=(12,6))

# %%
dff.plot.hist(figsize=(10,15),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f819fac2b70>,
# ...
#       dtype=object)

# %% [markdown]
# Visualizing single column

# %%
profit_greater = dff[dff['Profit']>5000]
profit_greater
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount     Profit
# 4190  Standard Class   Consumer  United States  ...        3      0.0  5039.9856
# 6826  Standard Class  Corporate  United States  ...        5      0.0  8399.9760
# 8153     First Class   Consumer  United States  ...        4      0.0  6719.9808
#
# [3 rows x 13 columns]

# %% [markdown]
# Cleaning the data

# %%
sales_greater = dff[dff['Sales']>5000]
sales_greater.head()
# Out:
#            Ship Mode      Segment        Country  ... Quantity Discount     Profit
# 165   Standard Class     Consumer  United States  ...        8      0.4 -1359.9920
# 509   Standard Class     Consumer  United States  ...        5      0.0  3177.4750
# 683         Same Day    Corporate  United States  ...        4      0.5 -3839.9904
# 2505    Second Class     Consumer  United States  ...        5      0.0   327.5060
# 2623     First Class  Home Office  United States  ...        4      0.2  3919.9888
#
# [5 rows x 13 columns]

# %%
sales_greater.plot.hist(figsize=(10,5))

# %%
profit_less = dff[dff['Profit']<5000]
profit_less.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %% [markdown]
# Checking profits based on categories

# %%
fix, ax = plt.subplots(figsize =(14,5))
dff.plot(x='Category', y="Sales",c='Profit',kind='scatter' ,ax=ax)

# %% [markdown]
# Checking profits based on sub-categories, quantities in state

# %%
fix, ax = plt.subplots(figsize =(20,6))
dff.plot(x='Sub-Category', y="Quantity",c='Profit',kind='scatter' ,ax=ax)

# %%
fix, ax = plt.subplots(figsize =(20,12))
dff.plot(x='Sub-Category', y="State",c='Profit',kind='scatter' ,ax=ax)

# %% [markdown]
# Checking Discount based on Ship Mode, categories and sub-categories in State

# %%
fix, ax = plt.subplots(figsize =(10,15))
dff.plot(x='Ship Mode', y='State', c='Discount',kind='scatter',ax=ax )

# %%
fix, ax = plt.subplots(figsize =(10,15))
dff.plot(x='Segment', y='State', c='Discount',kind='scatter',ax=ax )

# %%
fix, ax = plt.subplots(figsize =(10,12))
dff.plot(x='Category', y='State', c='Discount',kind='scatter',ax=ax )

# %%
fix, ax = plt.subplots(figsize =(18,12))
dff.plot(x='Sub-Category', y='State', c='Discount',kind='scatter',ax=ax )

# %%
dff.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
fix, ax = plt.subplots(figsize =(10,12))
dff.plot(x='Ship Mode', y='State', c='Profit',kind='scatter',ax=ax )

# %%
fix, ax = plt.subplots(figsize =(10,15))
dff.plot(x='Segment', y='State', c='Profit',kind='scatter',ax=ax )

# %%
import matplotlib.pyplot as plt
fix, ax = plt.subplots(figsize =(14,5))
dff.plot(kind= 'scatter', x='Sales', 
        y='Region', c='Profit',  ax=ax)

# %%
dff.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#oo method
import matplotlib.pyplot as plt
fix, ax = plt.subplots(figsize =(15,6))
dff.plot(kind= 'scatter', x='Quantity', 
        y='Sales', c='Profit', s=50, ax=ax)

# %%
#checking unique values
dff.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
dff['Profit'].unique()
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,  16.124 ,   4.1028,  72.948 ])

# %%
#relationship analysis

corr = dff.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
sns.heatmap(corr, xticklabels= corr.columns,yticklabels= corr.columns, annot=True)

# %%
# visualizing the relationship between each variable
sns.pairplot(corr)

# %%
#Building histograms
sns.distplot(corr['Profit'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(corr['Sales'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(corr['Quantity'])

# %%
import matplotlib.pyplot as plt
import numpy as np
#plt.figure(figsize= (25,9))
dd = corr.plot.hist(x='Sales',y='Profit')

# %%
X.shape
# Out:
# (5, 4)

# %%
Y.shape
# Out:
# (5,)

# %%
dd = dff.plot.hist(x='Ship Mode',y='Quantity')

# %%
dff['Sales'].plot()
